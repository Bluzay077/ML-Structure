# %%
pip install opencv-python scikit-image pillow

# %%
import cv2
img_cv = cv2.imread('images/zindagi.jpg')
type(img_cv)
img_cv.shape
cv2.imshow('Zindagi',img_cv)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt
img_plt = plt.imread('images/zindagi.jpg')
plt.figure(figsize=(16,7))
plt.imshow(img_plt);

# %%
chess = np.zeros([8, 8],dtype = np.uint8)

for i in range(8):
    for j in range(8):
        if (i%2==0 and j%2==0):
            chess[i:i+1, j:j+1] = 255
        elif (i%2!=0 and j%2!=0):
            chess[i:i+1, j:j+1] = 255

plt.imshow(chess , cmap='gray')

# %%
# Binary Thresholding
binary_image = img > 128
binary_image
binary_image.dtype
plt.imshow(binary_image, cmap='gray')


img = cv2.imread('images/zindagi.jpg', 0)
binary_image = img > 128
plt.figure(figsize=(16,9))
plt.subplot(1,2,1)
plt.imshow(img, cmap = 'gray')
plt.subplot(1,2,2)
plt.imshow(binary_image, cmap = 'gray')


thresh1, new_img = cv2.threshold(img, 128, 255, cv2.THRESH_BINARY)
thresh2, new_img_inv = cv2.threshold(img, 128, 255, cv2.THRESH_BINARY_INV)

plt.figure(figsize=(16,9))
plt.subplot(1,4,1); plt.title('Original Image')
plt.imshow(img, cmap = 'gray')
plt.subplot(1,4,2); plt.title('Using array operations')
plt.imshow(binary_image, cmap = 'gray')
plt.subplot(1,4,3); plt.title('Using functions with '+str(thresh1))
plt.imshow(new_img, cmap = 'gray')
plt.subplot(1,4,4); plt.title('Inverse Binary with '+str(thresh2))
plt.imshow(new_img_inv, cmap = 'gray')

# %%
# Otsu Thresholding
thresh, img_otsu = cv2.threshold(img, 100, 255, cv2.THRESH_OTSU)
plt.figure(figsize=(16,9))
plt.subplot(1,4,1); plt.title('Original Image')
plt.imshow(img, cmap = 'gray')
plt.subplot(1,4,2); plt.title('Otsu with '+str(thresh))
plt.imshow(img_otsu, cmap = 'gray')
plt.subplot(1,4,3); plt.title('Binary with '+str(thresh1))
plt.imshow(new_img, cmap = 'gray')
plt.subplot(1,4,4); plt.title('Inverse Binary with '+str(thresh2))
plt.imshow(new_img_inv, cmap = 'gray')

# %%
#Image Classification

thresh, img_otsu = cv2.threshold(img, 100, 255, cv2.THRESH_OTSU)
plt.figure(figsize=(16,9))
plt.subplot(1,4,1); plt.title('Original Image')
plt.imshow(img, cmap = 'gray')
plt.subplot(1,4,2); plt.title('Otsu with '+str(thresh))
plt.imshow(img_otsu, cmap = 'gray')
plt.subplot(1,4,3); plt.title('Binary with '+str(thresh1))
plt.imshow(new_img, cmap = 'gray')
plt.subplot(1,4,4); plt.title('Inverse Binary with '+str(thresh2))
plt.imshow(new_img_inv, cmap = 'gray')

(x_train, y_train), (x_test, y_test) = mnist.load_data()

plt.figure(figsize=(16,16))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow(x_train[i], cmap = 'gray')
    plt.title(y_train[i])
    plt.xticks([]); plt.yticks([])

# Normalize

x_train = x_train / 255
x_test = x_test / 255

x_train[0].shape
x_train[0].size

x_train = x_train.reshape(-1, x_train[0].size)
x_test = x_test.reshape(-1, x_train[0].size)

y_train_new = to_categorical(y_train)
y_test_new = to_categorical(y_test)

from keras.layers import Conv2D, MaxPool2D, Flatten

model = Sequential()

model.add(Input(shape=(28,28,1)))

model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPool2D((2, 2)))

model.add(Conv2D(16, (3, 3), activation='relu'))
model.add(MaxPool2D((2, 2)))

model.add(Flatten())
model.add(Dense(64, activation='relu'))

model.add(Dense(10, activation='softmax'))

model.summary()

# %%
# Predict on new image
img = cv2.imread('images/new-char1.jpg', 0)
img = cv2.resize(img, (28, 28))
thresh, img = cv2.threshold(img, 100, 255, cv2.THRESH_BINARY_INV)
img = img / 255
img = img.reshape(-1, x_train[0].size)
plt.imshow(img)

model.predict(img).argmax()

# %%
#color image 

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

labels = ['airplane','automobile','bird','cat',
          'deer','dog','frog','horse','ship','truck']
plt.figure(figsize=(16,16))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow(x_train[i])
    plt.title(labels[y_train[i][0]])
    plt.xticks([]); plt.yticks([])

model = Sequential()

model.add(Input(shape=(32,32,3)))

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(16, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))

model.add(Dense(10, activation='softmax'))

model.summary()

#predict on new data
img_1 = cv2.imread('datasets/fruits/sample1.jpg')
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)
img_1 = cv2.resize(img_1, (32,32))
plt.figure(figsize=(1,1))
plt.imshow(img_1)

img_1 = img_1.reshape(1,32,32,3)
